# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Imported all the required libaries and CIFAR100 datset

# %%
batch_size = 64
learning_rate = 3e-3
num_epochs = 50

# Data preprocessing and augmentation
data_gen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=True)

# %% [markdown]
# I have set the batch size to 64. I tried increasing and decreasing it and found this to be most optimum. Number of epochs that is iterations are currently set to 50 and can be further increased to increase the accuracy. Learning rate(used in optimization) has been set to 3e-3
#
# Data preprocessing is also done in this step.
# I divided it by 255 as rgb has value from 0-255 for each color

# %%
# Load the CIFAR-100 dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step

# %% [markdown]
# Loaded CIFAR100 dataset and splitted it for training and testing

# %%
# Convert labels to categorical format
y_train = tf.keras.utils.to_categorical(y_train, num_classes=100)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=100)

# %% [markdown]
# Converted training and testing labels to one-hot encoded categorical format with 100 classes.

# %%
data_gen.fit(x_train)
# Create data generators
train_generator = data_gen.flow(x_train, y_train, batch_size=batch_size)
test_generator = data_gen.flow(x_test, y_test, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Made batches with size equal to 64(set before) of already processed data

# %%
# Build the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(100, activation='softmax')
])

# %% [markdown]
#  I defined a convolutional neural network (CNN) from scratch using the Sequential API.I made a model which includes alternating convolutional layers with ReLU activation and max-pooling layers for feature extraction. Then, the extracted features are flattened and passed through fully connected layers with ReLU activation and dropout regularization to prevent overfitting. Finally, the output layer with softmax activation predicts the probabilities of the input image belonging to each of the 100 classes."

# %%
# Compile the model
optimizer = SGD(learning_rate=learning_rate, momentum=0.9, weight_decay=5e-4)
model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# In this part I compiled up my model using SGD optimizer with learning rate= 3e-3
#
# I tried using Adam optimizer as well but found this to be more optimum.
#
#  For loss calculation, I've used categorical cross-entropy, suitable for multi-class classification tasks.I'm also monitoring the accuracy metric to evaluate the model's performance.

# %%
# Train the model
history = model.fit(train_generator, epochs=num_epochs, validation_data=test_generator)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 19s 23ms/step - loss: 4.5486 - accuracy: 0.0215 - val_loss: 4.3097 - val_accuracy: 0.0527
# Epoch 2/50
# 782/782 [==============================] - 17s 22ms/step - loss: 4.1706 - accuracy: 0.0596 - val_loss: 3.8861 - val_accuracy: 0.1053
# Epoch 3/50
# 782/782 [==============================] - 17s 22ms/step - loss: 3.9058 - accuracy: 0.0914 - val_loss: 3.6443 - val_accuracy: 0.1390
# Epoch 4/50
# 782/782 [==============================] - 17s 22ms/step - loss: 3.7223 - accuracy: 0.1172 - val_loss: 3.4706 - val_accuracy: 0.1790
# Epoch 5/50
# 782/782 [==============================] - 17s 22ms/step - loss: 3.5610 - accuracy: 0.1432 - val_loss: 3.3073 - val_accuracy: 0.2086
# Epoch 6/50
# 782/782 [==============================] - 17s 22ms/step - loss: 3.4190 - accuracy: 0.1689 - val_loss: 3.1485 - val_accuracy: 0.2278
# Epoch 7/50
# 782/782 [==============================] - 17s 22ms/step - loss: 3.2843 - accuracy: 0.1935 - val_loss: 2.9988 - val_accuracy: 0.2593
# Epoch 8/50
# 782/782 [==============================] - 18s 22ms/step - loss: 3.1634 - accuracy: 0.2130 - val_loss: 2.9030 - val_accuracy: 0.2785
# Epoch 9/50
# 782/782 [==============================] - 17s 22ms/step - loss: 3.0296 - accuracy: 0.2389 - val_loss: 2.7628 - val_accuracy: 0.2963
# Epoch 10/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.9196 - accuracy: 0.2628 - val_loss: 2.6547 - val_accuracy: 0.3272
# Epoch 11/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.8255 - accuracy: 0.2803 - val_loss: 2.6147 - val_accuracy: 0.3316
# Epoch 12/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.7373 - accuracy: 0.2968 - val_loss: 2.5505 - val_accuracy: 0.3463
# Epoch 13/50
# 782/782 [==============================] - 18s 22ms/step - loss: 2.6592 - accuracy: 0.3145 - val_loss: 2.4631 - val_accuracy: 0.3612
# Epoch 14/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.5890 - accuracy: 0.3253 - val_loss: 2.4136 - val_accuracy: 0.3717
# Epoch 15/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.5318 - accuracy: 0.3379 - val_loss: 2.3581 - val_accuracy: 0.3839
# Epoch 16/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.4692 - accuracy: 0.3530 - val_loss: 2.3295 - val_accuracy: 0.3854
# Epoch 17/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.4077 - accuracy: 0.3635 - val_loss: 2.3069 - val_accuracy: 0.3977
# Epoch 18/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.3505 - accuracy: 0.3754 - val_loss: 2.2450 - val_accuracy: 0.4097
# Epoch 19/50
# 782/782 [==============================] - 18s 22ms/step - loss: 2.2975 - accuracy: 0.3873 - val_loss: 2.2235 - val_accuracy: 0.4212
# Epoch 20/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.2493 - accuracy: 0.3988 - val_loss: 2.1865 - val_accuracy: 0.4260
# Epoch 21/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.1889 - accuracy: 0.4110 - val_loss: 2.1884 - val_accuracy: 0.4247
# Epoch 22/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.1473 - accuracy: 0.4193 - val_loss: 2.1616 - val_accuracy: 0.4321
# Epoch 23/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.0997 - accuracy: 0.4314 - val_loss: 2.1654 - val_accuracy: 0.4323
# Epoch 24/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.0664 - accuracy: 0.4427 - val_loss: 2.1300 - val_accuracy: 0.4406
# Epoch 25/50
# 782/782 [==============================] - 17s 22ms/step - loss: 2.0003 - accuracy: 0.4564 - val_loss: 2.1218 - val_accuracy: 0.4398
# Epoch 26/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.9609 - accuracy: 0.4625 - val_loss: 2.0951 - val_accuracy: 0.4443
# Epoch 27/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.9204 - accuracy: 0.4721 - val_loss: 2.1021 - val_accuracy: 0.4426
# Epoch 28/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.8752 - accuracy: 0.4814 - val_loss: 2.0908 - val_accuracy: 0.4474
# Epoch 29/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.8341 - accuracy: 0.4891 - val_loss: 2.0809 - val_accuracy: 0.4544
# Epoch 30/50
# 782/782 [==============================] - 17s 21ms/step - loss: 1.8001 - accuracy: 0.5008 - val_loss: 2.0879 - val_accuracy: 0.4514
# Epoch 31/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.7572 - accuracy: 0.5074 - val_loss: 2.0674 - val_accuracy: 0.4602
# Epoch 32/50
# 782/782 [==============================] - 18s 23ms/step - loss: 1.7205 - accuracy: 0.5177 - val_loss: 2.0710 - val_accuracy: 0.4570
# Epoch 33/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.6732 - accuracy: 0.5276 - val_loss: 2.0966 - val_accuracy: 0.4629
# Epoch 34/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.6370 - accuracy: 0.5370 - val_loss: 2.0806 - val_accuracy: 0.4585
# Epoch 35/50
# 782/782 [==============================] - 17s 21ms/step - loss: 1.5990 - accuracy: 0.5480 - val_loss: 2.0778 - val_accuracy: 0.4603
# Epoch 36/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.5615 - accuracy: 0.5538 - val_loss: 2.0778 - val_accuracy: 0.4672
# Epoch 37/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.5354 - accuracy: 0.5593 - val_loss: 2.0596 - val_accuracy: 0.4719
# Epoch 38/50
# 782/782 [==============================] - 18s 22ms/step - loss: 1.4955 - accuracy: 0.5697 - val_loss: 2.0633 - val_accuracy: 0.4709
# Epoch 39/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.4509 - accuracy: 0.5791 - val_loss: 2.0977 - val_accuracy: 0.4685
# Epoch 40/50
# 782/782 [==============================] - 18s 22ms/step - loss: 1.4237 - accuracy: 0.5876 - val_loss: 2.0962 - val_accuracy: 0.4709
# Epoch 41/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.3892 - accuracy: 0.5943 - val_loss: 2.0984 - val_accuracy: 0.4708
# Epoch 42/50
# 782/782 [==============================] - 17s 21ms/step - loss: 1.3540 - accuracy: 0.6036 - val_loss: 2.1047 - val_accuracy: 0.4716
# Epoch 43/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.3417 - accuracy: 0.6088 - val_loss: 2.0633 - val_accuracy: 0.4754
# Epoch 44/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.2933 - accuracy: 0.6182 - val_loss: 2.1248 - val_accuracy: 0.4770
# Epoch 45/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.2799 - accuracy: 0.6252 - val_loss: 2.1066 - val_accuracy: 0.4765
# Epoch 46/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.2421 - accuracy: 0.6317 - val_loss: 2.1113 - val_accuracy: 0.4777
# Epoch 47/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.2038 - accuracy: 0.6447 - val_loss: 2.1595 - val_accuracy: 0.4774
# Epoch 48/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.1845 - accuracy: 0.6473 - val_loss: 2.1731 - val_accuracy: 0.4724
# Epoch 49/50
# 782/782 [==============================] - 17s 22ms/step - loss: 1.1549 - accuracy: 0.6550 - val_loss: 2.1541 - val_accuracy: 0.4798
# Epoch 50/50
# 782/782 [==============================] - 18s 22ms/step - loss: 1.1257 - accuracy: 0.6626 - val_loss: 2.1988 - val_accuracy: 0.4809

# %% [markdown]
# This is most important part which is training. I am training it using fit function. The model is trained on already processed train_data for specific number of epochs( currently I have set it to 50).
#
# Increasing the number of epochs can increase the accuracy.
#
# Additionally, I've  provided the test_generator for validation during training to monitor the model's performance on unseen data.

# %%
# Plot the training and validation loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()


# Plot the training and validation loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %% [markdown]
# In this part I plotted loss vs number of epochs and accuracy vs number of epochs to view the progress,
#
# I plotted it for validation data as well

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test loss: {test_loss:.4f}, Test accuracy: {test_acc:.4f}')
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 2.2067 - accuracy: 0.4739
# Test loss: 2.2067, Test accuracy: 0.4739

# %% [markdown]
# This is the final testing moment of model where I test my model on preprocessed test_data and calculate loss and accuracy. The accuracy comes out to be 45%
#
# The accuracy is not really great but can be further improved by increasing number of epochs or using transfer learning on pre trained models.
# .

# %%
# Function to display predictions
def display_images(model, test_generator, num_images=20):
    test_images, test_labels = next(test_generator)
    predictions = model.predict(test_images)
    class_names = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']

    num_cols = 2  # Number of columns in the subplot grid
    num_rows = num_images // num_cols  # Number of rows in the subplot grid

    plt.figure(figsize=(7, 5))  # Increase the figure size
    for i in range(num_images):
        plt.subplot(num_rows, num_cols, i + 1)
        plt.imshow(test_images[i])
        predicted_class = np.argmax(predictions[i])
        true_class = np.argmax(test_labels[i])
        class_name = class_names[predicted_class]
        plt.title(f'Predicted: {class_name}, Actual: {class_names[true_class]}', fontsize=5)  # Increase the font size
        plt.axis('off')
    plt.tight_layout()
    plt.show()

display_images(model, test_generator)
# Out:
# 2/2 [==============================] - 0s 6ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# This is just the testing part of my model where I take some random images and run my model on them. Then I print the actual and predicted classification to see how well my code works

# %% [markdown]
# ## **Acknowledgements**
#
# 1. ***https://github.com/shuoros/cifar100-resnet50-pytorch***
#
#     I refered to this code while working on this project. This code is made using
#     pytorch. I tried to understand this code and tried to implement same using keras and tensorflow.
#
# 2. ***Open AI ChatGpt***
#
#     I also used ChatGpt for helping me with some of keras and tensorflow libraries.

# %% [markdown]
# # **Areas of Improvement**
#
# 1. **Using Transfer learning**
#
#     I think incorporating any pre trained model like Resnet or VGG16 using transfer learning is the best way to increase the model effecincy. I tried using transfer learning but it increased the time so went along with this.
#
# 2. **Adding more layers**
#
#     Adding more layers can also increase the effeciency of the model. This is the basic model I tried to made
#
# 3. **Increasing Data size**
#
#     Increasing the train data size is also a good way to increase accuracy. This will increase the generalisation of the model. For now I went with CIFAR100 which has around 50000 images
#
# 4. **Changing Learning Rate**
#
#     Learning Rate also plays important role in deciding accuracy rate.

# %% [markdown]
# # **Difficulties Faced**
#
#
#
#
# 1. I was first working with COCO datset but it was very large and hence faced a lot of difficulty in working with the code. I later shifted to CIFAR100 and found it be most optimum.
#
# 2. I faced a lot of errors while training the model specially in shape
#    incompatibility and made a lot of modifications to finally rectify it.
#
# 3. Choosing an optimizer was also an task. I first chose Adam optimizer but found the accuracy lower than SGD optimizer so finally went ahead with this.
